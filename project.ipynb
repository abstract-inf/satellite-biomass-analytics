# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Complete_Dataset_updated.csv')
df.iloc[0:2,:]
# Out:
#        Date  DOY  Sample  Sub-Sample        Lat      Long_ Sample_type  \
# 0  7/6/2022  187       1           1 -20.446717 -54.839505          Q1
# 1  7/6/2022  187       1           2 -20.446717 -54.839505          Q1
#
#    Animals         DM        MM  ...     PRES_ATM    HUM_REL  TP_SFC_AVG  \
# 0        1  54.177195  6.869019  ...  1014.941667  47.458333   23.187826
# 1        1  54.177058  6.835684  ...  1014.941667  47.458333   23.187826
#
#      Wind_Dir  Dew_Point  Radiative_Dif_AVG  Radiative_Direct_AVG        PPFD  \
# 0  119.917171   8.584028         160.617416              7.444173  358.837504
# 1  119.917171   8.584028         160.617416              7.444173  358.837504
#
#    Longwave_Rad_AVG  Environmental Suitability Index
# 0        344.212487                         3.209516
# 1        344.212487                         5.109516
#
# [2 rows x 53 columns]
